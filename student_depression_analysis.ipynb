# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('depression.csv')
df
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
prova=df['Financial Stress']
np.mean(prova),min(prova),max(prova)
# Out:
# (3.1398666571080365, 1.0, 5.0)

# %%
gender=np.array(df['Gender'])
depression=np.array(df['Depression'])
history=np.array(df['Family History of Mental Illness'])
colors = ['#4B6A9B',  # Depressed: muted blue
          '#A8D5BA']

# %%
males=gender[gender=='Male']
females=gender[gender=='Female']
sizes=[len(males),len(females)]
labels=['Male','Female']
plt.pie(sizes,labels=labels,autopct='%1.1f%%',wedgeprops={'width': 0.4},pctdistance=0.78,colors=colors)
plt.title('Gender distribution', fontsize=18)
plt.show()

# %%
sizes=[sum(depression),sum(depression==0)]
labels=['Depressed','Not Depressed']
plt.pie(sizes,labels=labels,autopct='%1.1f%%',wedgeprops={'width': 0.4},pctdistance=0.78,colors=colors)
plt.title('Depression distribution',fontsize=18)
plt.show()

# %%
maledep=depression[gender=='Male']
femaledep=depression[gender=='Female']
sizes=[[sum(maledep),sum(femaledep)],[sum(maledep==0),sum(femaledep==0)]]
'''
fig, axs = plt.subplots(1,2,figsize=(16,9))
axs=axs.flatten()
labels=['Depressed','Not Depressed']
axs[0].pie(sizes[0],labels=labels,autopct='%1.1f%%')
axs[0].set_title('Male depression')
axs[1].pie(sizes[1],labels=labels,autopct='%1.1f%%')
axs[1].set_title('Female depression')
'''

barWidth = 0.25
fig = plt.subplots(figsize =(8, 6)) 

br1 = np.arange(len(sizes)) 
br2 = [x + barWidth for x in br1] 

plt.bar(br1, sizes[0], color ='r', width = barWidth, 
        edgecolor ='grey', label ='Depressed') 
plt.bar(br2, sizes[1], color ='g', width = barWidth, 
        edgecolor ='grey', label ='Not Depressed') 

#plt.xlabel('Branch', fontweight ='bold', fontsize = 15) 
plt.ylabel('Depressed', fontweight ='bold', fontsize = 15) 
plt.xticks([r + barWidth for r in range(2)], 
        ['Male', 'Female'])

plt.legend()

plt.show()

# %%
maledep=depression[gender=='Male']
femaledep=depression[gender=='Female']
sizes=[[sum(maledep),sum(maledep==0)],[sum(femaledep),sum(femaledep==0)]]
'''
fig, axs = plt.subplots(1,2,figsize=(16,9))
axs=axs.flatten()
labels=['Depressed','Not Depressed']
axs[0].pie(sizes[0],labels=labels,autopct='%1.1f%%')
axs[0].set_title('Male depression')
axs[1].pie(sizes[1],labels=labels,autopct='%1.1f%%')
axs[1].set_title('Female depression')
'''
colors = ['#4B6A9B',  # Depressed: muted blue
          '#A8D5BA'] 


labels=['Depressed','Not Depressed']
plt.pie(sizes[0],labels=labels,autopct='%1.1f%%',wedgeprops={'width': 0.4},pctdistance=0.78,colors=colors)
plt.title('Male Depression',fontsize=18)
plt.show()

# %%
plt.pie(sizes[1],labels=labels,autopct='%1.1f%%',wedgeprops={'width': 0.4},pctdistance=0.78,colors=colors)
plt.title('Female Depression',fontsize=18)
plt.show()

# %%
sizes=[]
cgpa=df['CGPA'].to_numpy()
depression=df['Depression'].to_numpy()
for i in range(5,10):
    imin=max(0,i)
    imax=min(10,i+1)
    if imax==10:
        fil=(cgpa<=imax) & (cgpa>=imin)
    else:
        fil=(cgpa<imax) & (cgpa>=imin)
    dep=depression[fil]
    sizes.append([sum(dep==True),sum(dep==False)])

sizes=np.array(sizes).T

barWidth = 0.25
fig = plt.subplots(figsize =(8, 6)) 

br1 = np.arange(5) 
br2 = [x + barWidth for x in br1] 

plt.bar(br1, sizes[0], color ='r', width = barWidth, 
        edgecolor ='grey', label ='Depressed') 
plt.bar(br2, sizes[1], color ='g', width = barWidth, 
        edgecolor ='grey', label ='Not Depressed') 

#plt.xlabel('Branch', fontweight ='bold', fontsize = 15) 
plt.ylabel('Depressed', fontweight ='bold', fontsize = 15) 
plt.xlabel('GPA', fontweight ='bold', fontsize = 15) 
plt.xticks([r + barWidth for r in range(5)], 
        ['5-6', '6-7','7-8','8-9','9-10'])

plt.legend()

plt.show()

# %%
newsizes=sizes[0]/(sizes[0]+sizes[1])
x=['5-6', '6-7','7-8','8-9','9-10']

# Create a bar plot
plt.bar(x, newsizes, edgecolor='black')

# Add title and labels
plt.ylabel('Depressed percentage', fontweight ='bold', fontsize = 15) 
plt.xlabel('GPA', fontweight ='bold', fontsize = 15) 
plt.ylim(top=1,bottom=0)

# Add the percentage value above each bar
for i, value in enumerate(newsizes):
    plt.text(i, value + 0.01, f'{value*100:.1f}%', ha='center')
plt.show()

# %%
sizes=[]
cgpa=df['Work/Study Hours'].to_numpy()
depression=df['Depression'].to_numpy()
for i in range(0,12,2):
    imin=max(0,i)
    imax=min(12,i+2)
    if imax==12:
        fil=(cgpa<=imax) & (cgpa>=imin)
    else:
        fil=(cgpa<imax) & (cgpa>=imin)
    dep=depression[fil]
    sizes.append([sum(dep==True),sum(dep==False)])

sizes=np.array(sizes).T

barWidth = 0.25
fig = plt.subplots(figsize =(8, 6)) 

br1 = np.arange(6) 
br2 = [x + barWidth for x in br1] 

plt.bar(br1, sizes[0], color ='r', width = barWidth, 
        edgecolor ='grey', label ='Depressed') 
plt.bar(br2, sizes[1], color ='g', width = barWidth, 
        edgecolor ='grey', label ='Not Depressed') 

#plt.xlabel('Branch', fontweight ='bold', fontsize = 15) 
plt.ylabel('Depressed', fontweight ='bold', fontsize = 15) 
plt.xlabel('Work/Study hours per Day', fontweight ='bold', fontsize = 15) 
plt.xticks([r + barWidth for r in range(6)], 
        ['0-2','2-4','4-6','6-8','8-10','10-12',])

plt.legend()

plt.show()

# %%
sizes=[]
cgpa=df['Study Satisfaction'].to_numpy()
depression=df['Depression'].to_numpy()
for i in range(1,6):
    fil=(cgpa==i)
    dep=depression[fil]
    sizes.append([sum(dep==True),sum(dep==False)])

sizes=np.array(sizes).T

barWidth = 0.25
fig = plt.subplots(figsize =(8, 6)) 

br1 = np.arange(5) 
br2 = [x + barWidth for x in br1] 

plt.bar(br1, sizes[0], color ='r', width = barWidth, 
        edgecolor ='grey', label ='Depressed') 
plt.bar(br2, sizes[1], color ='g', width = barWidth, 
        edgecolor ='grey', label ='Not Depressed') 

#plt.xlabel('Branch', fontweight ='bold', fontsize = 15) 
plt.ylabel('Depressed', fontweight ='bold', fontsize = 15) 
plt.xlabel('Study Satisfaction', fontweight ='bold', fontsize = 15) 
plt.xticks([r + barWidth for r in range(5)], 
        ['1','2','3','4','5'])

plt.legend()

plt.show()

# %%
sizes=[]
cgpa=df['Academic Pressure'].to_numpy()
depression=df['Depression'].to_numpy()
for i in range(1,6):
    fil=(cgpa==i)
    dep=depression[fil]
    sizes.append([sum(dep==True),sum(dep==False)])

sizes=np.array(sizes).T

barWidth = 0.25
fig = plt.subplots(figsize =(8, 6)) 

br1 = np.arange(5) 
br2 = [x + barWidth for x in br1] 

plt.bar(br1, sizes[0], color ='r', width = barWidth, 
        edgecolor ='grey', label ='Depressed') 
plt.bar(br2, sizes[1], color ='g', width = barWidth, 
        edgecolor ='grey', label ='Not Depressed') 

#plt.xlabel('Branch', fontweight ='bold', fontsize = 15) 
plt.ylabel('Depressed', fontweight ='bold', fontsize = 15) 
plt.xlabel('Academic Pressure', fontweight ='bold', fontsize = 15) 
plt.xticks([r + barWidth for r in range(5)], 
        ['1','2','3','4','5'])

plt.legend()

plt.show()

# %%
sizes=[]
cgpa=df['Financial Stress'].to_numpy()
depression=df['Depression'].to_numpy()
for i in range(1,6):
    fil=(cgpa==i)
    dep=depression[fil]
    sizes.append([sum(dep==True),sum(dep==False)])

sizes=np.array(sizes).T

barWidth = 0.25
fig = plt.subplots(figsize =(8, 6)) 

br1 = np.arange(5) 
br2 = [x + barWidth for x in br1] 

plt.bar(br1, sizes[0], color ='r', width = barWidth, 
        edgecolor ='grey', label ='Depressed') 
plt.bar(br2, sizes[1], color ='g', width = barWidth, 
        edgecolor ='grey', label ='Not Depressed') 

#plt.xlabel('Branch', fontweight ='bold', fontsize = 15) 
plt.ylabel('Depressed', fontweight ='bold', fontsize = 15) 
plt.xlabel('Financial Stress', fontweight ='bold', fontsize = 15) 
plt.xticks([r + barWidth for r in range(5)], 
        ['1','2','3','4','5'])

plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

sizes=[[0 for _ in range(6)] for _ in range(5)]
cgpa=df['CGPA'].to_numpy()
wshw=df['Work/Study Hours'].to_numpy()
depression=df['Depression'].to_numpy()
for i in range(5,10):
    imin=max(0,i)
    imax=min(10,i+1)
    for j in range(0,12,2):
        jmin=max(0,j)
        jmax=min(12,j+2)
        if imax==10 and jmax==12:
            fil=(cgpa<=imax) & (cgpa>=imin) & (wshw<=jmax) & (wshw>=jmin)
        elif imax==10 and jmax!=12:
            fil=(cgpa<=imax) & (cgpa>=imin) & (wshw<jmax) & (wshw>=jmin)
        elif imax!=10 and jmax==12:
            fil=(cgpa<imax) & (cgpa>=imin) & (wshw<=jmax) & (wshw>=jmin)
        else:
            fil=(cgpa<imax) & (cgpa>=imin) & (wshw<jmax) & (wshw>=jmin)
        dep=depression[fil]
        sizes[i-5][int(j/2)]=sum(dep==True)/len(dep)
        
depression_scores=np.array(sizes).T
gpas=['5-6', '6-7','7-8','8-9','9-10']
hours_of_study=['0-2','2-4','4-6','6-8','8-10','10-12']

sizes=np.array(sizes).T
# Create the plot
fig, ax = plt.subplots()

# Display the depression scores as a grid of numbers
cax = ax.matshow(depression_scores, cmap="coolwarm", alpha=0.3)

# Add the numbers inside the grid
for i in range(len(hours_of_study)):
    for j in range(len(gpas)):
        ax.text(j, i, f"{depression_scores[i,j]:.2f}", va='center', ha='center')

# Set axis labels
ax.set_xticks(np.arange(len(gpas)))
ax.set_yticks(np.arange(len(hours_of_study)))

# Set the axis labels
ax.set_xticklabels(gpas)
ax.set_yticklabels(hours_of_study)

# Rotate the tick labels for better readability
plt.xticks(rotation=45)

# Set axis labels
ax.set_xlabel('GPA')
ax.set_ylabel('Hours of Daily Work/Study')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

totscore=0
sizes=[[0 for _ in range(5)] for _ in range(5)]
cgpa=df['CGPA'].to_numpy()
wshw=df['Study Satisfaction'].to_numpy()
depression=df['Depression'].to_numpy()
for i in range(5,10):
    imin=max(0,i)
    imax=min(10,i+1)
    for j in range(1,6):
        if imax==10:
            fil=(cgpa<=imax) & (cgpa>=imin) & (wshw==j)
        else:
            fil=(cgpa<imax) & (cgpa>=imin) & (wshw==j)
        dep=depression[fil]
        totscore+=len(dep)
        sizes[i-5][int(j-1)]=sum(dep==True)/len(dep)
        
depression_scores=np.array(sizes).T
gpas=['5-6', '6-7','7-8','8-9','9-10']
hours_of_study=['1','2','3','4','5']

sizes=np.array(sizes).T
# Create the plot
fig, ax = plt.subplots()

# Display the depression scores as a grid of numbers
cax = ax.matshow(depression_scores, cmap="coolwarm", alpha=0.3)

# Add the numbers inside the grid
for i in range(len(hours_of_study)):
    for j in range(len(gpas)):
        ax.text(j, i, f"{depression_scores[i,j]:.2f}", va='center', ha='center')

# Set axis labels
ax.set_xticks(np.arange(len(gpas)))
ax.set_yticks(np.arange(len(hours_of_study)))

# Set the axis labels
ax.set_xticklabels(gpas)
ax.set_yticklabels(hours_of_study)

# Rotate the tick labels for better readability
plt.xticks(rotation=45)

# Set axis labels
ax.set_xlabel('GPA')
ax.set_ylabel('Study Satisfaction')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

totscore=0
sizes=[[0 for _ in range(6)] for _ in range(5)]
cgpa=df['Study Satisfaction'].to_numpy()
wshw=df['Work/Study Hours'].to_numpy()
depression=df['Depression'].to_numpy()
for i in range(1,6):
    for j in range(0,12,2):
        jmin=max(0,j)
        jmax=min(12,j+2)
        if jmax==12:
            fil=(cgpa==i) & (wshw<=jmax) & (wshw>=jmin)
        else:
            fil=(cgpa==i) & (wshw<jmax) & (wshw>=jmin)
        dep=depression[fil]
        totscore+=len(dep)
        sizes[i-1][int(j/2)]=sum(dep==True)/len(dep)
        
depression_scores=np.array(sizes).T
gpas=['1','2','3','4','5']
hours_of_study=['0-2','2-4','4-6','6-8','8-10','10-12',]

sizes=np.array(sizes).T
# Create the plot
fig, ax = plt.subplots()

# Display the depression scores as a grid of numbers
cax = ax.matshow(depression_scores, cmap="coolwarm", alpha=0.3)

# Add the numbers inside the grid
for i in range(len(hours_of_study)):
    for j in range(len(gpas)):
        ax.text(j, i, f"{depression_scores[i,j]:.2f}", va='center', ha='center')

# Set axis labels
ax.set_xticks(np.arange(len(gpas)))
ax.set_yticks(np.arange(len(hours_of_study)))

# Set the axis labels
ax.set_xticklabels(gpas)
ax.set_yticklabels(hours_of_study)

# Rotate the tick labels for better readability
plt.xticks(rotation=45)

# Set axis labels
ax.set_ylabel('Hours of Daily Work/Study')
ax.set_xlabel('Study Satisfaction')
print(totscore)
plt.show()
# Out:
# 27891

# %%
import numpy as np
import matplotlib.pyplot as plt

totscore=0
sizes=[[0 for _ in range(5)] for _ in range(5)]
cgpa=df['Academic Pressure'].to_numpy()
wshw=df['Financial Stress'].to_numpy()
depression=df['Depression'].to_numpy()
for i in range(1,6):
    for j in range(1,6):
        fil=(cgpa==i) & (wshw==j)
        dep=depression[fil]
        totscore+=len(dep)
        sizes[i-1][int(j-1)]=sum(dep==True)/len(dep)
        
depression_scores=np.array(sizes).T
gpas=['1','2','3','4','5']
hours_of_study=['1','2','3','4','5']

sizes=np.array(sizes).T
# Create the plot
fig, ax = plt.subplots()

# Display the depression scores as a grid of numbers
cax = ax.matshow(depression_scores, cmap="coolwarm", alpha=0.3)

# Add the numbers inside the grid
for i in range(len(hours_of_study)):
    for j in range(len(gpas)):
        ax.text(j, i, f"{depression_scores[i,j]:.2f}", va='center', ha='center')

# Set axis labels
ax.set_xticks(np.arange(len(gpas)))
ax.set_yticks(np.arange(len(hours_of_study)))

# Set the axis labels
ax.set_xticklabels(gpas)
ax.set_yticklabels(hours_of_study)

# Rotate the tick labels for better readability
plt.xticks(rotation=45)

# Set axis labels
ax.set_ylabel('Financial Stress')
ax.set_xlabel('Academic Pressure')
print(totscore)
plt.show()
# Out:
# 27889

# %%
sizes=[]
cgpa=df['CGPA'].to_numpy()
satis=df['Study Satisfaction'].to_numpy()
depression=df['Depression'].to_numpy()
for i in range(5,10):
    sizes.append([])
    imin=max(0,i)
    imax=min(10,i+1)
    if imax==10:
        fil=(cgpa<=imax) & (cgpa>=imin)
    else:
        fil=(cgpa<imax) & (cgpa>=imin)
    partial=satis[fil]
    for j in range(1,6):
        sizes[i-5].append(sum(partial==j))

sizes=np.array(sizes).T

barWidth = 0.15
fig = plt.subplots(figsize =(8, 6)) 
br1 = np.arange(5) 
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]
br5 = [x + barWidth for x in br4]

plt.bar(br1, sizes[0], color='#8da0cb', width=barWidth, edgecolor='grey', label='Satisfaction 1')  # soft blue
plt.bar(br2, sizes[1], color='#fc8d62', width=barWidth, edgecolor='grey', label='Satisfaction 2')  # soft coral
plt.bar(br3, sizes[2], color='#66c2a5', width=barWidth, edgecolor='grey', label='Satisfaction 3')  # soft green
plt.bar(br4, sizes[3], color='#1b9e77', width=barWidth, edgecolor='grey', label='Satisfaction 4')  # muted pink
plt.bar(br5, sizes[4], color='#a6d854', width=barWidth, edgecolor='grey', label='Satisfaction 5')  # lime pastel

#plt.xlabel('Branch', fontweight ='bold', fontsize = 15) 
plt.ylabel('Percentage', fontweight ='bold', fontsize = 15) 
plt.xlabel('GPA', fontweight ='bold', fontsize = 15) 
plt.xticks([r + barWidth for r in range(5)], 
        ['5-6', '6-7','7-8','8-9','9-10'])

plt.legend()

plt.show()

# %%
sizes=[]
cgpa=df['CGPA'].to_numpy()
satis=df['Academic Pressure'].to_numpy()
depression=df['Depression'].to_numpy()
for i in range(5,10):
    sizes.append([])
    imin=max(0,i)
    imax=min(10,i+1)
    if imax==10:
        fil=(cgpa<=imax) & (cgpa>=imin)
    else:
        fil=(cgpa<imax) & (cgpa>=imin)
    partial=satis[fil]
    for j in range(1,6):
        sizes[i-5].append(sum(partial==j))

sizes=np.array(sizes).T

barWidth = 0.15
fig = plt.subplots(figsize =(8, 6)) 
br1 = np.arange(5) 
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]
br5 = [x + barWidth for x in br4]

plt.bar(br1, sizes[0], color='#8da0cb', width=barWidth, edgecolor='grey', label='Satisfaction 1')  # soft blue
plt.bar(br2, sizes[1], color='#fc8d62', width=barWidth, edgecolor='grey', label='Satisfaction 2')  # soft coral
plt.bar(br3, sizes[2], color='#66c2a5', width=barWidth, edgecolor='grey', label='Satisfaction 3')  # soft green
plt.bar(br4, sizes[3], color='#1b9e77', width=barWidth, edgecolor='grey', label='Satisfaction 4')  # muted pink
plt.bar(br5, sizes[4], color='#a6d854', width=barWidth, edgecolor='grey', label='Satisfaction 5')  # lime pastel

#plt.xlabel('Branch', fontweight ='bold', fontsize = 15) 
plt.ylabel('Percentage', fontweight ='bold', fontsize = 15) 
plt.xlabel('GPA', fontweight ='bold', fontsize = 15) 
plt.xticks([r + barWidth for r in range(5)], 
        ['5-6', '6-7','7-8','8-9','9-10'])

plt.legend()

plt.show()

# %%
sizes=[]
cgpa=df['CGPA'].to_numpy()
satis=df['Work/Study Hours'].to_numpy()
depression=df['Depression'].to_numpy()
for i in range(5,10):
    sizes.append([])
    imin=max(0,i)
    imax=min(10,i+1)
    if imax==10:
        fil=(cgpa<=imax) & (cgpa>=imin)
    else:
        fil=(cgpa<imax) & (cgpa>=imin)
    partial=satis[fil]
    for j in range(0,12,2):
        jmin=max(0,j)
        jmax=min(12,j+2)
        if jmax!=12:
            bro=(partial>=jmin) & (partial<jmax)
        else:
            bro=((partial>=jmin) & (partial<=jmax))
        sizes[i-5].append(sum(bro==True))
    print(sum(sizes[i-5]))
    print(bro.size)

sizes=np.array(sizes).T
print(sizes)
barWidth = 0.15
fig = plt.subplots(figsize =(8, 6)) 
br1 = np.arange(5) 
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]
br5 = [x + barWidth for x in br4]

plt.bar(br1, sizes[0], color='#8da0cb', width=barWidth, edgecolor='grey', label='Satisfaction 1')  # soft blue
plt.bar(br2, sizes[1], color='#fc8d62', width=barWidth, edgecolor='grey', label='Satisfaction 2')  # soft coral
plt.bar(br3, sizes[2], color='#66c2a5', width=barWidth, edgecolor='grey', label='Satisfaction 3')  # soft green
plt.bar(br4, sizes[3], color='#1b9e77', width=barWidth, edgecolor='grey', label='Satisfaction 4')  # muted pink
plt.bar(br5, sizes[4], color='#a6d854', width=barWidth, edgecolor='grey', label='Satisfaction 5')  # lime pastel

#plt.xlabel('Branch', fontweight ='bold', fontsize = 15) 
plt.ylabel('Percentage', fontweight ='bold', fontsize = 15) 
plt.xlabel('GPA', fontweight ='bold', fontsize = 15) 
plt.xticks([r + barWidth for r in range(5)], 
        ['5-6', '6-7','7-8','8-9','9-10'])

plt.legend()

plt.show()
# Out:
# 5403
# 5403
# 4311
# 4311
# 5543
# 5543
# 6403
# 6403
# 6232
# 6232
# [[ 556  429  576  625  663]
#  [ 575  454  615  682  732]
#  [ 620  424  537  633  696]
#  [ 850  698  826  973  901]
#  [ 891  715  887 1033 1007]
#  [1911 1591 2102 2457 2233]]
